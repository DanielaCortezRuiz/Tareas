# %% [markdown]
# # Semana 9 Clase 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ruta=" https://raw.githubusercontent.com/marinlopabi/Temas-Selectos-PQ-AD-Python/refs/heads/main/Datos/contam2022.csv"

# %%
df=pd.read_csv(ruta)
df
# Out:
#           Fecha  Centro Ozono  Centro diÛxido de azufre  \
# 0    2022-01-01     36.916667                  6.333333
# 1    2022-01-02     17.250000                  7.750000
# 2    2022-01-03     24.083333                  7.833333
# 3    2022-01-04     27.583333                 27.416667
# 4    2022-01-05     30.875000                 12.833333
# ..          ...           ...                       ...
# 360  2022-12-27     19.041667                  5.750000
# 361  2022-12-28     17.041667                 11.000000
# 362  2022-12-29     14.083333                  4.750000
# 363  2022-12-30     12.416667                  4.916667
# 364  2022-12-31     13.291667                  2.833333
#
#      Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# 0                      22.458333                   10.208333   106.916667
# 1                      15.833333                    9.500000    97.875000
# ...

# %%
df.head() #da las  primeras cinco filas
# Out:
#         Fecha  Centro Ozono  Centro diÛxido de azufre  \
# 0  2022-01-01     36.916667                  6.333333
# 1  2022-01-02     17.250000                  7.750000
# 2  2022-01-03     24.083333                  7.833333
# 3  2022-01-04     27.583333                 27.416667
# 4  2022-01-05     30.875000                 12.833333
#
#    Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# 0                    22.458333                   10.208333   106.916667
# 1                    15.833333                    9.500000    97.875000
# 2                    17.875000                    5.041667    61.958333
# 3                    27.125000                    8.250000    91.333333
# 4                    25.791667                    9.791667    94.000000

# %%
df.head(11)
# Out:
#          Fecha  Centro Ozono  Centro diÛxido de azufre  \
# 0   2022-01-01     36.916667                  6.333333
# 1   2022-01-02     17.250000                  7.750000
# 2   2022-01-03     24.083333                  7.833333
# 3   2022-01-04     27.583333                 27.416667
# 4   2022-01-05     30.875000                 12.833333
# 5   2022-01-06     25.583333                  8.916667
# 6   2022-01-07     12.333333                  7.833333
# 7   2022-01-08     22.583333                  6.500000
# 8   2022-01-09     24.708333                  4.500000
# 9   2022-01-10     21.500000                  7.000000
# 10  2022-01-11     11.958333                  4.583333
#
#     Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# 0                     22.458333                   10.208333   106.916667
# 1                     15.833333                    9.500000    97.875000
# 2                     17.875000                    5.041667    61.958333
# ...

# %%
df.tail()
# Out:
#           Fecha  Centro Ozono  Centro diÛxido de azufre  \
# 360  2022-12-27     19.041667                  5.750000
# 361  2022-12-28     17.041667                 11.000000
# 362  2022-12-29     14.083333                  4.750000
# 363  2022-12-30     12.416667                  4.916667
# 364  2022-12-31     13.291667                  2.833333
#
#      Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# 360                    18.541667                    5.583333    39.500000
# 361                    19.125000                    8.583333    53.666667
# 362                    16.791667                    7.625000    42.416667
# 363                    17.625000                   10.166667    45.500000
# 364                    12.666667                    5.541667    37.583333

# %%
df.tail(11)
# Out:
#           Fecha  Centro Ozono  Centro diÛxido de azufre  \
# 354  2022-12-21     15.416667                 13.666667
# 355  2022-12-22     22.500000                  7.416667
# 356  2022-12-23     29.958333                  7.666667
# 357  2022-12-24     16.291667                 17.500000
# 358  2022-12-25     13.416667                  5.750000
# 359  2022-12-26     14.875000                  4.750000
# 360  2022-12-27     19.041667                  5.750000
# 361  2022-12-28     17.041667                 11.000000
# 362  2022-12-29     14.083333                  4.750000
# 363  2022-12-30     12.416667                  4.916667
# 364  2022-12-31     13.291667                  2.833333
#
#      Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# 354                    17.708333                    5.500000    67.541667
# 355                    24.750000                   10.041667    62.208333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Fecha                        365 non-null    object
#  1   Centro Ozono                 365 non-null    float64
#  2   Centro diÛxido de azufre     365 non-null    float64
#  3   Centro diÛxido de nitrÛgeno  365 non-null    float64
#  4   Centro monÛxido de carbono   365 non-null    float64
#  5   Centro PM10                  365 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 17.2+ KB

# %%
df.describe() # estadistivca escriptiva
# Out:
#        Centro Ozono  Centro diÛxido de azufre  Centro diÛxido de nitrÛgeno  \
# count    365.000000                365.000000                   365.000000
# mean      27.238470                  7.128311                    15.446575
# std       10.683100                  5.100674                     3.789316
# min        9.625000                  2.000000                     7.458333
# 25%       18.666667                  4.000000                    12.500000
# 50%       25.708333                  5.666667                    15.250000
# 75%       33.916667                  8.416667                    17.875000
# max       67.000000                 34.416667                    29.666667
#
#        Centro monÛxido de carbono  Centro PM10
# count                  365.000000   365.000000
# mean                     5.365868    49.600000
# std                      1.750875    18.261962
# min                      2.208333    15.125000
# 25%                      4.041667    35.583333
# ...

# %%
df.describe(include="all") # incluye columnas no numericas
# Out:
#              Fecha  Centro Ozono  Centro diÛxido de azufre  \
# count          365    365.000000                365.000000
# unique         365           NaN                       NaN
# top     2022-12-31           NaN                       NaN
# freq             1           NaN                       NaN
# mean           NaN     27.238470                  7.128311
# std            NaN     10.683100                  5.100674
# min            NaN      9.625000                  2.000000
# 25%            NaN     18.666667                  4.000000
# 50%            NaN     25.708333                  5.666667
# 75%            NaN     33.916667                  8.416667
# max            NaN     67.000000                 34.416667
#
#         Centro diÛxido de nitrÛgeno  Centro monÛxido de carbono  Centro PM10
# count                    365.000000                  365.000000   365.000000
# unique                          NaN                         NaN          NaN
# ...

# %%
df.columns #ver colunas
# Out:
# Index(['Fecha', 'Centro Ozono', 'Centro diÛxido de azufre',
#        'Centro diÛxido de nitrÛgeno', 'Centro monÛxido de carbono',
#        'Centro PM10'],
#       dtype='object')

# %% [markdown]
# La codificación

# %% [markdown]
# las computadoras cinvierten el texto en numeros para guardarlos y leerlos.
#
# UTF-8

# %% [markdown]
# Archivo TXT

# %% [markdown]
# Se puede leer con read_csv

# %%
ruta="https://raw.githubusercontent.com/marinlopabi/Temas-Selectos-PQ-AD-Python/refs/heads/main/Datos/lista_uami.txt"

# %%
df=pd.read_csv(ruta,sep="\t")  # sep= tipo de sepradores, encontrar el adecuado de acuerdo al tipo de datos
df
# Out:
#          TRIMESTRE                           UEA  \
# 0              25P                       2132044
# 1              NaN                           NaN
# 2            LUNES                        MARTES
# 3   12:00 - 14:00                            NaN
# 4             E005                           NaN
# 5             E005                           NaN
# 6             E005                           NaN
# 7         PROFESOR                        NOMBRE
# 8            37031  MARTINEZ CADENA JUAN ALBERTO
# 9          RENGLON                     MATRICULA
# 10               1                      22420196
# 11               2                      22330537
# 12               3                      22120176
# 13               4                      22420184
# 14               5                      22420189
# 15               6                      22430143
# 16               7                      22420186
# 17               8                      22420193
# ...

# %%
df.head()
# Out:
#         TRIMESTRE      UEA           GRUPO    CUPO INSCRITOS  \
# 0             25P  2132044            HC03      50        50
# 1             NaN      NaN   ESTADISTICA I     NaN       NaN
# 2           LUNES   MARTES       MIERCOLES  JUEVES   VIERNES
# 3  12:00 - 14:00       NaN             NaN     NaN       NaN
# 4            E005      NaN  12:00 - 14:00      NaN       NaN
#
#    TIPO DE EVALUACION
# 0         221238050.0
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
ruta="https://raw.githubusercontent.com/marinlopabi/Temas-Selectos-PQ-AD-Python/refs/heads/main/Datos/signals.txt"

# %%
df0=pd.read_csv(ruta,delim_whitespace=True)  # sep= tipo de sepradores, encontrar el adecuado de acuerdo al tipo de datos
df0
# Out:
# /tmp/ipython-input-1557997086.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df0=pd.read_csv(ruta,delim_whitespace=True)  # sep= tipo de sepradores, encontrar el adecuado de acuerdo al tipo de datos
#         num   signal_A   signal_B
# 0      8293 -20.913280 -18.689188
# 1      7455 -10.544383  15.727543
# 2      a001  -0.465730   0.197600
# 3      a002   0.375698   0.120031
# 4      a003   0.647689   0.059630
# ...     ...        ...        ...
# 997    a996  -0.281100   1.070150
# 998    a997   1.797687  -0.026521
# 999    a998   0.640843  -0.881875
# 1000   a999  -0.571179  -0.163067
# 1001  a1000   0.572583  -0.744903
#
# [1002 rows x 3 columns]

# %%
df.head()
# Out:
#     num   signal_A   signal_B
# 0  8293 -20.913280 -18.689188
# 1  7455 -10.544383  15.727543
# 2  a001  -0.465730   0.197600
# 3  a002   0.375698   0.120031
# 4  a003   0.647689   0.059630

# %% [markdown]
# Para un archivo excel

# %%
ruta="https://raw.githubusercontent.com/marinlopabi/Temas-Selectos-PQ-AD-Python/refs/heads/main/Datos/nacimientos.xlsx"

# %%
df1=pd.read_excel(ruta)
df1
# Out:
#                    Estado Abreviatura    Regiones  Mujeres  Hombres  No_esp  \
# 0          Aguascalientes          AG     Noreste    10410    10796       0
# 1         Baja California          BC    Noroeste    29944    30732       0
# 2     Baja California Sur          BS    Noroeste     5396     5732       0
# 3                Campeche          CM     Sureste     6841     7049       0
# 4    Coahuila de Zaragoza          CO     Noreste    22835    23471       0
# 5                  Colima          CL   Occidente     4404     4721       0
# 6                 Chiapas          CS     Sureste    72880    78684       0
# 7               Chihuahua          CH    Noroeste    25458    26231       0
# 8                    CDMX          CX  Centro-Sur    43610    44789       0
# 9                 Durango          DG    Noroeste    14859    15248       0
# 10             Guanajuato          GT     Noreste    48392    49754       0
# ...

# %% [markdown]
# archivos JSON

# %%
ruta="https://raw.githubusercontent.com/marinlopabi/Temas-Selectos-PQ-AD-Python/refs/heads/main/Datos/localidades_100.json"

# %%
df2= pd.read_json(ruta)
df2
# Out:
#            localidade 1 localidade 2         localidade 3 localidade 4  \
# Continente         Ásia         Ásia      América Central       Europa
# País              Índia        Japão            Guatemala  Reino Unido
# Capital       Nova Deli       Tóquio  Cidade da Guatemala      Londres
#
#            localidade 5 localidade 6 localidade 7      localidade 8  \
# Continente       Europa       África       Europa  América do Norte
# País        Reino Unido      Nigéria       Itália    Estados Unidos
# Capital         Londres        Abuja         Roma     Washington DC
#
#              localidade 9     localidade 10  ... localidade 91 localidade 92  \
# Continente        Oceania  América do Norte  ...        Europa        África
# País        Nova Zelândia    Estados Unidos  ...      Alemanha       Nigéria
# Capital        Wellington     Washington DC  ...        Berlim         Abuja
#
#            localidade 93 localidade 94     localidade 95     localidade 96  \
# ...

# %% [markdown]
# Limpieza de datos

# %%
df.dtypes # el tipo de dato de cada columna
# Out:
# Estado         object
# Abreviatura    object
# Regiones       object
# Mujeres         int64
# Hombres         int64
# No_esp          int64
# Total           int64
# dtype: object

# %%
df1.dtypes
# Out:
# Estado         object
# Abreviatura    object
# Regiones       object
# Mujeres         int64
# Hombres         int64
# No_esp          int64
# Total           int64
# dtype: object

# %%
df2.dtypes
# Out:
# localidade 1      object
# localidade 2      object
# localidade 3      object
# localidade 4      object
# localidade 5      object
#                    ...
# localidade 96     object
# localidade 97     object
# localidade 98     object
# localidade 99     object
# localidade 100    object
# Length: 100, dtype: object

# %% [markdown]
# objetos= cadenas de texto
#
# enteros=numeros enteros

# %% [markdown]
# Convertir datos de un tipo a otro

# %%
df2.select_dtypes(include=["int64", "float64"])
# Out:
# Empty DataFrame
# Columns: []
# Index: [Continente, País, Capital]

# %%
df1.select_dtypes(include=["int64", "float64"])
# Out:
#     Mujeres  Hombres  No_esp   Total
# 0     10410    10796       0   21206
# 1     29944    30732       0   60676
# 2      5396     5732       0   11128
# 3      6841     7049       0   13890
# 4     22835    23471       0   46306
# 5      4404     4721       0    9125
# 6     72880    78684       0  151564
# 7     25458    26231       0   51689
# 8     43610    44789       0   88399
# 9     14859    15248       0   30107
# 10    48392    49754       0   98146
# 11    35840    36055       0   71895
# 12    18724    19246       0   37970
# 13    64423    66707       0  131130
# 14   108808   111544       1  220353
# 15    39561    41152       0   80713
# 16    13088    13845       0   26933
# 17     8934     9251       0   18185
# 18    40669    41790       0   82459
# 19    29186    30090       0   59276
# 20    55168    57153       0  112321
# 21    15950    16443       0   32393
# 22    13294    13792       0   27086
# 23    20853    21558       0   42411
# ...

# %%
df2.select_dtypes(include=["object"]) #selecciona columnas de texto
# Out:
#            localidade 1 localidade 2         localidade 3 localidade 4  \
# Continente         Ásia         Ásia      América Central       Europa
# País              Índia        Japão            Guatemala  Reino Unido
# Capital       Nova Deli       Tóquio  Cidade da Guatemala      Londres
#
#            localidade 5 localidade 6 localidade 7      localidade 8  \
# Continente       Europa       África       Europa  América do Norte
# País        Reino Unido      Nigéria       Itália    Estados Unidos
# Capital         Londres        Abuja         Roma     Washington DC
#
#              localidade 9     localidade 10  ... localidade 91 localidade 92  \
# Continente        Oceania  América do Norte  ...        Europa        África
# País        Nova Zelândia    Estados Unidos  ...      Alemanha       Nigéria
# Capital        Wellington     Washington DC  ...        Berlim         Abuja
#
#            localidade 93 localidade 94     localidade 95     localidade 96  \
# ...

# %%
df0.rename(columns={"signal_A":"Señal A"}, inplace=True)
df0.rename(columns={"signal_B":"Señal B"}, inplace=True)

# %%
df0
# Out:
#         num    Señal A    Señal B
# 0      8293 -20.913280 -18.689188
# 1      7455 -10.544383  15.727543
# 2      a001  -0.465730   0.197600
# 3      a002   0.375698   0.120031
# 4      a003   0.647689   0.059630
# ...     ...        ...        ...
# 997    a996  -0.281100   1.070150
# 998    a997   1.797687  -0.026521
# 999    a998   0.640843  -0.881875
# 1000   a999  -0.571179  -0.163067
# 1001  a1000   0.572583  -0.744903
#
# [1002 rows x 3 columns]

# %%
df0.rename (columns={
    "Señal A":" A",
    "Señal B":" B",
}, inplace=True)

# %%
df0
# Out:
#         num          A          B
# 0      8293 -20.913280 -18.689188
# 1      7455 -10.544383  15.727543
# 2      a001  -0.465730   0.197600
# 3      a002   0.375698   0.120031
# 4      a003   0.647689   0.059630
# ...     ...        ...        ...
# 997    a996  -0.281100   1.070150
# 998    a997   1.797687  -0.026521
# 999    a998   0.640843  -0.881875
# 1000   a999  -0.571179  -0.163067
# 1001  a1000   0.572583  -0.744903
#
# [1002 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# TRIMESTRE              1
# UEA                    5
# GRUPO                  3
# CUPO                  57
# INSCRITOS             58
# TIPO DE EVALUACION    59
# dtype: int64

# %%
df.isna().sum().sum() # tatal de datos faltantes en el data frame
# Out:
# np.int64(183)

# %%
(df.isna().sum()/ len(df))*100
# Out:
# TRIMESTRE              1.666667
# UEA                    8.333333
# GRUPO                  5.000000
# CUPO                  95.000000
# INSCRITOS             96.666667
# TIPO DE EVALUACION    98.333333
# dtype: float64

# %%
df.isna().sum()[df.isna().sum()== 0]
# Out:
# Series([], dtype: int64)
